# %%
import pandas as pd
import stock_data
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Data Pull

# %%
sdata = stock_data.StockData()
spy_df = sdata.get_price_history('SPY', '1990-01-01', '2023-09-30', '1mo')
spy_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date        Open        High         Low       Close   Adj Close  \
# 0   1993-02-01   43.968750   45.125000   42.812500   44.406250   25.296394
# 1   1993-03-01   44.562500   45.843750   44.218750   45.187500   25.741444
# 2   1993-04-01   45.250000   45.250000   43.281250   44.031250   25.201248
# 3   1993-05-01   44.093750   45.656250   43.843750   45.218750   25.880899
# 4   1993-06-01   45.375000   45.812500   44.218750   45.062500   25.791460
# ..         ...         ...         ...         ...         ...         ...
# 360 2023-02-01  405.209991  418.309998  393.640015  396.260010  393.292480
# 361 2023-03-01  395.410004  409.700012  380.649994  409.390015  406.324188
# 362 2023-04-01  408.850006  415.940002  403.779999  415.929993  414.390686
# 363 2023-05-01  415.470001  422.579987  403.739990  417.850006  416.303619
# 364 2023-06-01  418.089996  443.899994  416.790009  433.209991  433.209991
#
# ...

# %%
df = sdata.get_bb(spy_df, 20, 2).dropna().reset_index(drop=True)
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   1994-09-01   47.500000   47.718750   45.734375   46.171875   27.297684
# 1   1994-10-01   46.203125   47.703125   45.000000   47.484375   28.244402
# 2   1994-11-01   47.281250   47.328125   44.609375   45.593750   27.119835
# 3   1994-12-01   45.640625   46.406250   44.687500   45.562500   27.101248
# 4   1995-01-01   45.703125   47.234375   45.687500   47.093750   28.235413
# ..         ...         ...         ...         ...         ...         ...
# 341 2023-02-01  405.209991  418.309998  393.640015  396.260010  393.292480
# 342 2023-03-01  395.410004  409.700012  380.649994  409.390015  406.324188
# 343 2023-04-01  408.850006  415.940002  403.779999  415.929993  414.390686
# 344 2023-05-01  415.470001  422.579987  403.739990  417.850006  416.303619
# 345 2023-06-01  418.089996  443.899994  416.790009  433.209991  433.209991
#
#          Volume          ub          ma          lb
# ...

# %%
df[['Date', 'Close', 'lb']].head(50)
# Out:
#          Date       Close         lb
# 0  1994-09-01   46.171875  43.538042
# 1  1994-10-01   47.484375  43.669004
# 2  1994-11-01   45.593750  43.710550
# 3  1994-12-01   45.562500  43.966606
# 4  1995-01-01   47.093750  44.047007
# 5  1995-02-01   49.015625  43.944150
# 6  1995-03-01   50.109375  43.775299
# 7  1995-04-01   51.593750  43.248069
# 8  1995-05-01   53.640625  42.554640
# 9  1995-06-01   54.406250  41.945533
# 10 1995-07-01   56.156250  41.309411
# 11 1995-08-01   56.406250  40.899684
# 12 1995-09-01   58.484375  40.236831
# 13 1995-10-01   58.312500  39.984327
# 14 1995-11-01   60.906250  39.898108
# 15 1995-12-01   61.484375  39.967311
# 16 1996-01-01   63.671875  39.911615
# 17 1996-02-01   63.875000  40.399433
# 18 1996-03-01   64.687500  40.837476
# 19 1996-04-01   65.390625  41.182864
# 20 1996-05-01   66.875000  41.905063
# 21 1996-06-01   67.109375  42.663330
# 22 1996-07-01   64.093750  44.322687
# 23 1996-08-01   65.328125  46.258121
# ...

# %% [markdown]
# ## Strategy 1 - Buy BB

# %%
import simulator as sim
s = sim.Simulator(1000, df)
#s.strategy_sim(0.05).to_csv('chk2.csv', index=False)
s1 = s.strategy_sim(0.05)
s1['sim_results']
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   1994-09-01   47.500000   47.718750   45.734375   46.171875   27.297684
# 1   1994-10-01   46.203125   47.703125   45.000000   47.484375   28.244402
# 2   1994-11-01   47.281250   47.328125   44.609375   45.593750   27.119835
# 3   1994-12-01   45.640625   46.406250   44.687500   45.562500   27.101248
# 4   1995-01-01   45.703125   47.234375   45.687500   47.093750   28.235413
# ..         ...         ...         ...         ...         ...         ...
# 341 2023-02-01  405.209991  418.309998  393.640015  396.260010  393.292480
# 342 2023-03-01  395.410004  409.700012  380.649994  409.390015  406.324188
# 343 2023-04-01  408.850006  415.940002  403.779999  415.929993  414.390686
# 344 2023-05-01  415.470001  422.579987  403.739990  417.850006  416.303619
# 345 2023-06-01  418.089996  443.899994  416.790009  433.209991  433.209991
#
# ...

# %%
s1['return']
# Out:
# {'final_acc_balance': 937823.5377284016, 'CAGR': '26.78834867130673 %'}

# %% [markdown]
# ## Strategy 2 - DCA

# %%
import simulator as sim
s = sim.Simulator(1000, df)
s2 = s.dca_sim()

# %%
s2['return']
# Out:
# {'final_acc_balance': 1146981.3259171094, 'CAGR': '27.67673871269136 %'}

# %% [markdown]
# ## Final Results

# %%
df_final = s1['sim_results'][['Date', 'Close', 'num_shares_bought', 'cash_to_invest']]
df_final = df_final.rename(columns={'num_shares_bought':'s1_num_shares_bought',
                                    'cash_to_invest': 's1_cash_to_invest'})
df_final = df_final.merge(s2['sim_results'][['Date', 'num_shares_bought', 'cash_to_invest']], on='Date')
df_final = df_final.rename(columns={'num_shares_bought':'s2_num_shares_bought',
                                    'cash_to_invest': 's2_cash_to_invest'})
df_final['year'] = df_final['Date'].dt.to_period('Y')
df_final
# Out:
#           Date       Close  s1_num_shares_bought  s1_cash_to_invest  \
# 0   1994-09-01   46.171875              0.000000               1000
# 1   1994-10-01   47.484375              0.000000               2000
# 2   1994-11-01   45.593750             65.798492                  0
# 3   1994-12-01   45.562500             21.947874                  0
# 4   1995-01-01   47.093750              0.000000               1000
# ..         ...         ...                   ...                ...
# 341 2023-02-01  396.260010              0.000000               5000
# 342 2023-03-01  409.390015              0.000000               6000
# 343 2023-04-01  415.929993              0.000000               7000
# 344 2023-05-01  417.850006              0.000000               8000
# 345 2023-06-01  433.209991              0.000000               9000
#
#      s2_num_shares_bought  s2_cash_to_invest  year
# 0               21.658206               1000  1994
# ...

# %%
df_final_g = df_final.groupby('year').agg({'s1_num_shares_bought':'sum',
                                           's2_num_shares_bought':'sum',
                                           'Close': 'last'}).reset_index()
df_final_g['s1_num_shares_bought_cumsum'] = np.cumsum(df_final_g['s1_num_shares_bought'])
df_final_g['s2_num_shares_bought_cumsum'] = np.cumsum(df_final_g['s2_num_shares_bought'])
df_final_g['s1_value'] = df_final_g['Close']*df_final_g['s1_num_shares_bought_cumsum']
df_final_g['s2_value'] = df_final_g['Close']*df_final_g['s2_num_shares_bought_cumsum']
df_final_g
# Out:
#     year  s1_num_shares_bought  s2_num_shares_bought       Close  \
# 0   1994             87.746366             86.598470   45.562500
# 1   1995              0.000000            220.463789   61.484375
# 2   1996              0.000000            178.261373   73.843750
# 3   1997              0.000000            137.981417   97.062500
# 4   1998              0.000000            110.760757  123.312500
# 5   1999              0.000000             90.360171  146.875000
# 6   2000            544.357853             84.566123  131.187500
# 7   2001             85.722551            101.471796  114.300003
# 8   2002            114.932521            122.630656   88.230003
# 9   2003              0.000000            124.438243  111.279999
# 10  2004              0.000000            105.511734  120.870003
# 11  2005              0.000000             99.326424  124.510002
# 12  2006              0.000000             91.046448  141.619995
# ...
